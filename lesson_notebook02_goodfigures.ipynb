# %% [markdown]
# ## While you are waiting, follow the instructions in Canvas.

# %% [markdown]
# # Reproducible Science in R and Figures (Part 2)
#
# <img src="https://zenodo.org/record/3332808/files/1728_TURI_Book%20sprint_5%20turing%20way_040619.jpg" alt="Drawing" style="display:block; margin:auto; width:30%">

# %% [markdown]
# ## Skills you will have by the end of this lesson
# - Create publication-quality figures
# - Writing reuseable code for making figures
# - Save figures in a variety of formats
# - Avoid rewriting code for similar figures

# %% [markdown]
# > Images from [The Turing Way](https://the-turing-way.netlify.app/reproducible-research/reproducible-research.html)!
#
#
# <img src="https://github.com/the-turing-way/the-turing-way/blob/main/book/website/figures/reusable-code-garden.png?raw=true" alt="Drawing" style="display:block; margin:auto; width: 600px;"/>

# %% [markdown]
# ## Putting Together What You Have Learnt
#
# <img src="https://allisonhorst.github.io/palmerpenguins/reference/figures/lter_penguins.png" alt="Drawing" style="display:block; margin:auto; width: 800px;"/>

# %% [markdown]
# Last time we made a new RProject and cleaned up some Palmer penguin data.
#
# We now want to continue from where we left off.

# %% [markdown]
# ### Find Your Project Folder and Double-Click your `.RProj` File
#
# - RStudio opens up to your Project
# - The working directory is automatically set to this folder
# - The name of your project is in the top right of the RStudio window

# %% [markdown]
# ## Check Canvas to see the code you should have.
#
# <img src="image/directory_007.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# ## Renv
#
# Check you have a `renv` folder in your project.
#
# This is a safe place for us to install our packages for this project and keep the rest of our computer tidy.
#
# <img src="https://rstudio.github.io/renv/logo.svg" alt="Drawing" style="display:block; margin:auto;width: 200px;"/>

# %% [markdown]
# ## If your renv folder is missing
#
# `renv::init()`

# %% [markdown]
# ## What is renv for?
#
# - We will install libraries for our penguin project
# - This keeps track of what we need and what versions they were
# - We can use this to install the same versions of libraries on other people's computers
# - It means in 5 years we can still run our code

# %% [markdown]
# ## With an renv folder, it will keep track of what we install.

# %% [markdown]
# <img src="image/directory_010_start.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# ## Sharing our Work
#
# <img src="https://media.licdn.com/dms/image/D4D12AQFPEOmOOcwwAg/article-cover_image-shrink_720_1280/0/1706896285400?e=2147483647&v=beta&t=73kWgIE31oQoowaRCTQM_E0WvgIQPDbi2_rFRXmxJ30" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# ## Go to your GitHub account and create a new repository
#
# ### `https://github.com/new`
#
# - Make sure it is the same name as your project (PenguinProject)
# - Don't initialise with a README, license or gitignore

# %% [markdown]
# <img src="image/github_001_newrepo.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/><img src="image/github_002_newrepo.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# <img src="image/github_003_newrepo.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# ## Check RStudio is connected to GitHub
#
# In the console:
# `ssh -T git@github.com`
#
# It should say hello to you!
#
# > If not, go and follow the instructions in Canvas.

# %% [markdown]
# ### Now tell RStudio who you are on GitHub
#
# `git config --global user.email "<YOUR_EMAIL>"`
#
# `git config --global user.name "<YOUR_NAME>"`
#
# If this doesn't work, double check these are the same as your GitHub account. If it doesn't work, don't worry. We can still push our files to GitHub.

# %% [markdown]
# ## Linking our GitHub Repository to RStudio
#
# `git remote add origin <YOUR_REPO_URL>`
#
# <img src="image/github_005_remote.png" alt="Drawing" style="display:block; margin:auto; width: 500px;"/>

# %% [markdown]
# ## Paste that line into the RStudio console
#
# `git remote add origin <YOUR_REPO_URL>`
#
#
# <img src="https://jofrhwld.github.io/blog/posts/2022/12/2022-12-21_github-onboarding/github_onboarding_assets/rstudio_console.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# ## Now we can send our files to GitHub.
#
# Have a look at the Git tab in the top right.
#
# <img src="image/git_001_panel.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# ### You'll see your files listed.
#
# Select them using the tick boxes and then click `Commit`.
#
# <img src="image/git_002_add.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# ### A window will come up
#
# You can see what is new and what changes have happened.
# Green means added, red means removed.
#
# <img src="image/git_003_diff.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# ### Write a useful commit message
#
# - We could write "Initialise files"
# - Usually commits are for small changes and we would commit often.
# - This keeps our code very safe
#
# <img src="image/git_004_message.png" alt="Drawing" style="display:block; margin:auto; width: 200px;"/>

# %% [markdown]
# ### The commit will now go through
#
# <img src="image/git_005_terminal.png" alt="Drawing" style="display:block; margin:auto; width: 300px;"/>

# %% [markdown]
# ### We can now push our files to GitHub
#
# - A commit is like saving
# - A push actually sends the files to GitHub
#
# <img src="image/git_006_push.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>
# >
# <img src="image/git_007_github.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# ## You can go to GitHub and see your files there.

# %% [markdown]
# ### One of the files that has been uploaded to Github is called `renv.lock`
#
# - This is what will tell others what libraries we used.
# - When someone else downloads the repository, they can run `renv::restore()` to install the same libraries we used.
#
# <img src="https://rstudio.github.io/renv/logo.svg" alt="Drawing" style="display:block; margin:auto;width: 200px;"/>

# %% [markdown]
# # Creating Publication-Quality Figures
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Ggplot2_hex_logo.png/1920px-Ggplot2_hex_logo.png" alt="Drawing" style="display:block; margin:auto; width: 200px;"/>

# %% [markdown]
# ### Continue in our RMarkdown file
#
# - You can switch your code over to Quarto if you prefer

# %%
# In the console
install.packages("ggplot2")

# At the top of your script
library(tidyverse)
library(here)
library(janitor)

source(here("functions", "cleaning.R"))


# The rest of your script

# ---- Save the clean data ----
# write_csv(penguins_clean, here("data", "penguins_clean.csv"))
# -------------------------------------
# Out:
# The following package(s) will be installed:
# - ggplot2 [3.5.1]
# These packages will be installed into "~/Library/CloudStorage/OneDrive-Nexus365/000_AlanTuring/004_REG/001_Teaching/R_teaching/renv/library/macos/R-4.4/aarch64-apple-darwin22.6.0".
#
# # Installing packages --------------------------------------------------------
# - Installing ggplot2 ...                        OK [linked from cache]
# ...

# %% [markdown]
# ### We need a new library

# %%
# Put at the top of your script

library(ggplot2)

# %% [markdown]
# ## A boxplot with ggplot2

# %% [markdown]
# ### Exploratory Figure
#
# - An exploratory figure shows the reader the raw data
# - Before any modelling, you need to demonstrate the shape of the data
# - This is a good way to check your data is looking as you expect

# %%
penguins_raw <- read_csv(here("data", "penguins_raw.csv"))

penguins_clean <- penguins_raw %>%
  clean_column_names() %>%
  remove_columns(c("comments", "delta")) %>%
  shorten_species() %>%
  remove_empty_columns_rows()

names(penguins_clean)
# Out:
# New names:
# • `` -> `...1`
#  [1] "x1"                "study_name"        "sample_number"
#  [4] "species"           "region"            "island"
#  [7] "stage"             "individual_id"     "clutch_completion"
# [10] "date_egg"          "culmen_length_mm"  "culmen_depth_mm"
# [13] "flipper_length_mm" "body_mass_g"       "sex"

# %%
### A place to start
penguins_clean <- read_csv(here("data", "penguins_clean.csv"))

flipper_boxplot <- ggplot(
  data = penguins_clean, 
  aes(x = species, 
      y = flipper_length_mm)) +
  geom_boxplot()

flipper_boxplot
# Out:
# Rows: 344 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (8): study_name, species, region, island, stage, individual_id, clutch_...
# dbl  (6): x1, sample_number, culmen_length_mm, culmen_depth_mm, flipper_leng...
# date (1): date_egg
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# plot without title

# %% [markdown]
# ## One of the warnings is because we have some `NA` values in our data
#
# - First we should subset the columns first
# - We should remove the NA values from only the columns we are interested in

# %%
# Subset the columns: species and flipper_length_mm
penguins_flippers <- penguins_clean %>%
  select(species, flipper_length_mm)

# %%
# We can use our `remove_NA` function in cleaning.R to remove the NA values
penguins_flippers <- drop_na(penguins_flippers)

# %% [markdown]
# ### ⚠️ **We are overwriting**.
#
# Take some time to now make a pipe with these functions instead.

# %%
# Better code to subset and remove NA values and not overwrite

penguins_flippers <- penguins_clean %>%
  select(species, flipper_length_mm) %>%
  drop_na()

# %% [markdown]
# ### Now try our boxplot again

# %%
flipper_boxplot <- ggplot(
    data = penguins_flippers, 
    aes(x = species,  
        y = flipper_length_mm)) +
    geom_boxplot()

flipper_boxplot
# Out:
# plot without title

# %% [markdown]
# ## The errors are gone but this is a very ugly figure
#
# - We can walk through making it better

# %%
flipper_boxplot <- ggplot(
    data = penguins_flippers, 
    aes(x = species, 
        y = flipper_length_mm)) +
    geom_boxplot(aes(color = species), 
                show.legend = FALSE) +
    geom_jitter(aes(color = species), 
                show.legend = FALSE)
                          

flipper_boxplot
# Out:
# plot without title

# %% [markdown]
# ### Random Seed
#
# `geom_jitter` plots the data in y. However, if it plotted in x, all the markers would exist in a straight line.
#
# - The function gives each point a random x value within a certain width to make the markers more visible. In this case the x variable for the markers is therefore meaningless.

# %% [markdown]
# The problem with asking a computer to generate randomness is a) it is not truly random b) it is not reproducible! If you wanted to make sure you produce the same image every time, instead your markers would differ each time. In this example, it really doesn't matter, but any random aspect of your analysis should be repeatable.
#
# To do this, I specified a `random_seed = 0`. This means it will make the same randomness every time I run it.

# %%
flipper_boxplot <- ggplot(
    data = penguins_flippers, 
    aes(
        x = species, 
        y = flipper_length_mm)) +
    geom_boxplot(
        aes(color = species), 
        width = 0.3, 
        show.legend = FALSE) +
    geom_jitter(
        aes(color = species),
        show.legend = FALSE, 
        position = position_jitter(
            width = 0.2, 
            seed = 0))

flipper_boxplot
# Out:
# plot without title

# %% [markdown]
# ### Transparency
#
# When considering how transparent your elements are, the terminology is its `alpha` value, where 1 is opaque and 0 is completely transparent. Here I gave the `geom_jitter` an `alpha = 0.3` setting.

# %%
flipper_boxplot <- ggplot(
    data = penguins_flippers, 
    aes(
        x = species, 
        y = flipper_length_mm)) +
    geom_boxplot(
        aes(color = species), 
        width = 0.3, 
        show.legend = FALSE) +
    geom_jitter(
        aes(color = species),
        alpha = 0.3,
        show.legend = FALSE, 
        position = position_jitter(width = 0.2, seed = 0))

flipper_boxplot
# Out:
# plot without title

# %% [markdown]
# ### Fix the labels

# %%
flipper_boxplot <- ggplot(
    data = penguins_flippers, 
    aes(x = species, 
        y = flipper_length_mm)) +
    geom_boxplot(aes(color = species), 
                width = 0.3, 
                show.legend = FALSE) +
    geom_jitter(aes(color = species), 
                alpha = 0.3,
                show.legend = FALSE,
                position = position_jitter(
                    width = 0.2, 
                    seed = 0)) +
    labs(x = "Species",
         y = "Flipper Length (mm)")

flipper_boxplot
# Out:
# plot without title

# %% [markdown]
# ### Following the Palmer penguin colours
#
# <img src="https://allisonhorst.github.io/palmerpenguins/reference/figures/lter_penguins.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %%
# Define color mapping with names for each species
species_colours <- c("Adelie" = "darkorange", 
                    "Chinstrap" = "purple", 
                    "Gentoo" = "cyan4")

flipper_boxplot <- ggplot(
    data = penguins_flippers, 
    aes(
        x = species, 
        y = flipper_length_mm)) +
    geom_boxplot(
        aes(color = species), 
            width = 0.3, 
            show.legend = FALSE) +
    geom_jitter(
        aes(color = species), 
        alpha = 0.3,
        show.legend = FALSE,
        position = position_jitter(
            width = 0.2, 
            seed = 0)) +
    scale_color_manual(values = species_colours) +
    labs(x = "Species",
                               y = "Flipper Length (mm)")

flipper_boxplot
# Out:
# plot without title

# %% [markdown]
# ### Themes
#
# We would like to get rid of the grey background and make the grid a different colour. We can use a `theme` to sort these elements for us.
#
# There is no need to start editing the grid and backgrounds manually!

# %%
species_colours <- c("Adelie" = "darkorange", 
                    "Chinstrap" = "purple", 
                    "Gentoo" = "cyan4")

flipper_boxplot <- ggplot(
    data = penguins_flippers, 
    aes(
        x = species, 
        y = flipper_length_mm)) +
    geom_boxplot(
        aes(color = species), 
        width = 0.3, 
        show.legend = FALSE) +
    geom_jitter(
        aes(color = species), 
        width = 0.3, 
        alpha = 0.3,
        show.legend = FALSE) +
    scale_color_manual(
        values = species_colours) + 
    labs(
        x = "Species",
        y = "Flipper Length (mm)") + 
    theme_bw()

flipper_boxplot
# Out:
# plot without title

# %% [markdown]
# ## If we like, we can make this code into a function
#
# - We could make a new file in `functions` called `plotting.R`
# - Move our function inside
# - Load the function at the top of our script with `source()`
#
# `source(here("functions", "plotting.R"))`

# %% [markdown]
# <img src="image/directory_190_functions.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %%
                    
                    
plot_boxplot <- function(data, species_colours) {

    # First remove NA values
    data <- data %>%
        drop_na(flipper_length_mm)
    
    # Now make the plot
    ggplot(data = data, 
           aes(
            x = species, 
            y = flipper_length_mm, 
            color = species)) +  
        geom_boxplot(
            width = 0.3, 
            show.legend = FALSE) +
        geom_jitter(
            alpha = 0.3,
            show.legend = FALSE,
            position = position_jitter(
            width = 0.2, seed = 0)) +
        scale_color_manual(
            values = species_colours) +  
        labs(
            x = "Species", 
            y = "Flipper Length (mm)") +  
        theme_bw()
}

species_colours <- c("Adelie" = "darkorange", 
                    "Chinstrap" = "purple", 
                    "Gentoo" = "cyan4")
                    
plot_boxplot(penguins_clean, species_colours)
# Out:
# plot without title

# %% [markdown]
# ## However, it makes more sense to have a flexible function

# %%
species_colours <- c("Adelie" = "darkorange", 
                    "Chinstrap" = "purple", 
                    "Gentoo" = "cyan4")
                    
                    
plot_boxplot <- function(data, 
                         x_column, 
                         y_column, 
                         x_label, 
                         y_label, 
                         colour_mapping) {

    # First remove NA values
    data <- data %>%
        drop_na({{ y_column }})
    
    # Now make the plot
    ggplot(data = data, 
           aes(
            x = {{ x_column }}, 
            y = {{ y_column }}, 
            color = {{ x_column }})) +  # Use {{ }} for x and y columns
        geom_boxplot(
            width = 0.3, 
            show.legend = FALSE) +
        geom_jitter(
            alpha = 0.3,
            size = 1,
            show.legend = FALSE,
            position = position_jitter(width = 0.2, seed = 0)) +
        scale_color_manual(
            values = colour_mapping) +  # Use color_mapping input here
        labs(
            x = x_label, 
            y = y_label) +  # Use provided x and y labels
        theme_bw()
}

plot_boxplot(penguins_clean, 
             species, flipper_length_mm, 
             "Species", "Flipper Length (mm)", 
             species_colours)
# Out:
# plot without title

# %%
plot_boxplot(penguins_clean, species, body_mass_g, "Species", "Body Mass (g)", species_colours)
# Out:
# plot without title

# %% [markdown]
# ## We can use this function to make four subplots

# %%
# Ignore this 
options(repr.plot.width = 4, repr.plot.height = 4, repr.plot.res = 300)

# %%
# 2 by 2 grid subplots
# options(repr.plot.width = 8, repr.plot.height = 8, repr.plot.res = 300)

library(patchwork)

# Create individual subplots with different y-axis columns
plot1 <- plot_boxplot(
    penguins_clean, species, flipper_length_mm, 
    "Penguin Species", "Flipper Length (mm)", 
    species_colours)

plot2 <- plot_boxplot(
    penguins_clean, species, culmen_length_mm, 
    "Penguin Species", "Bill Length (mm)", 
    species_colours)

plot3 <- plot_boxplot(
    penguins_clean, species, culmen_depth_mm, 
    "Penguin Species", "Bill Depth (mm)", 
    species_colours)

plot4 <- plot_boxplot(
    penguins_clean, species, body_mass_g, 
    "Penguin Species", "Body Mass (g)", 
    species_colours)

# Combine plots in a 2x2 grid
combined_plot <- (plot1 | plot2) / (plot3 | plot4)
combined_plot
# Out:
# plot without title

# %% [markdown]
# # Saving Plots
#
# - No rewriting any code!

# %% [markdown]
# ## Make a subfolder called `figures`
#
# <img src="image/directory_200_figures.png" alt="Drawing" style="display:block; margin:auto; width: 400px;"/>

# %% [markdown]
# ## We need another couple of libraries

# %%
# In the console
# install.packages("ragg")
# install.packages("svglite")

# # Update renv
# renv::snapshot()

# ---- At the top of your script ----
library(ragg)
library(svglite)

# %%
flipper_boxplot <- plot_boxplot(penguins_clean, 
                                species, flipper_length_mm, 
                                "Species", "Flipper Length (mm)", 
                                species_colours)

agg_png("figures/penguin_boxplot_default.png", 
        width = 20, 
        height = 20, 
        units = "cm", 
        res = 300, 
        scaling = 1)
print(flipper_boxplot)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# <img src="figures/penguin_boxplot_default.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# ## Change the Scale
#
# - Don't change fonts manually!

# %%
flipper_boxplot <- plot_boxplot(penguins_clean, 
                                species, flipper_length_mm, 
                                "Species", "Flipper Length (mm)", 
                                species_colours)

agg_png("figures/penguin_boxplot_2.png", 
        width = 20, height = 20, units = "cm", res = 300, scaling = 2)
print(flipper_boxplot)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# <img src="figures/penguin_boxplot_2.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# ## Try reducing the resolution

# %%
flipper_boxplot <- plot_boxplot(penguins_clean, 
                                species, flipper_length_mm, 
                                "Species", "Flipper Length (mm)", 
                                species_colours)

agg_png("figures/penguin_boxplot_lowres.png", 
        width = 20, height = 20, units = "cm", res = 50, scaling = 2)
print(flipper_boxplot)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# <img src="figures/penguin_boxplot_lowres.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# ## Increase the size for a poster

# %%
flipper_boxplot <- plot_boxplot(penguins_clean, species, flipper_length_mm, "Species", "Flipper Length (mm)", species_colours)

agg_png("figures/penguin_boxplot_poster.png", 
        width = 40, height = 40, units = "cm", res = 300, scaling = 2)
print(flipper_boxplot)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# <img src="figures/penguin_boxplot_poster.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# ### We forgot to change the scaling

# %%
flipper_boxplot <- plot_boxplot(penguins_clean, 
                                species, flipper_length_mm, 
                                "Species", "Flipper Length (mm)", 
                                species_colours)

agg_png("figures/penguin_boxplot_poster2.png", 
        width = 40, height = 40, units = "cm", res = 300, scaling = 4)
print(flipper_boxplot)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# <img src="figures/penguin_boxplot_poster2.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# ### Now our poster and report figures are identical but different sizes
#
# <img src="figures/penguin_boxplot_2.png" alt="Drawing" style="width: 200px;"/>
# <img src="figures/penguin_boxplot_poster2.png" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# ## We may want to make a PowerPoint figure

# %%
flipper_boxplot <- plot_boxplot(penguins_clean, 
                                species, flipper_length_mm, 
                                "Species", "Flipper Length (mm)", 
                                species_colours)

agg_png("figures/penguin_boxplot_powerpoint.png", 
        width = 20, 
        height = 20, 
        units = "cm", 
        res = 300, 
        scaling = 3)
print(flipper_boxplot)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# <img src="figures/penguin_boxplot_powerpoint.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# ## Using Vectors Rather than PNG
#
# - Vector graphics are better for high resolution
# - No fuzzy pixels when you zoom in or scale it up

# %% [markdown]
# ### What happens when you zoom into png
#
# <img src="https://i.imgur.com/T6GOBzc.png" alt="Drawing" style="width: 300px;"/>

# %% [markdown]
# ### Where possible, you should try to make your images *vectors* instead. These have the filetype `.svg` or `.pdf`.

# %%
flipper_boxplot <- plot_boxplot(penguins_clean, 
                                species, flipper_length_mm, 
                                "Species", "Flipper Length (mm)", 
                                species_colours)
inches_conversion = 2.54
svglite("figures/penguin_boxplot_vector.svg", 
        width = 20 / inches_conversion, 
        height = 20 / inches_conversion, 
        scaling = 2)
print(flipper_boxplot)
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# <img src="figures/penguin_boxplot_vector.svg" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# ### Zooming into an SVG
#
# <img src="https://i.imgur.com/D7vR9CL.png" alt="Drawing" style="width: 300px;"/>

# %% [markdown]
# ## We can make a function to save our plots

# %%
save_flipper_plot_png <- function(boxplot, 
                                  filename, size, res, scaling){
  agg_png(filename, width   =  size, 
                    height  =  size, 
                    units   =  "cm", 
                    res     =  res, 
                    scaling =  scaling)
  print(boxplot)
  dev.off()
}

flipper_boxplot <- plot_boxplot(penguins_clean, 
                                species, flipper_length_mm, 
                                "Species", "Flipper Length (mm)", 
                                species_colours)

save_flipper_plot_png(flipper_boxplot, 
                       here("figures", "flipper_boxplot_report.png"), 
                       size = 20, res = 300, scaling = 2)

save_flipper_plot_png(flipper_boxplot, 
                       here("figures", "flipper_boxplot_poster.png"), 
                       size = 40, res = 300, scaling = 4)

save_flipper_plot_png(flipper_boxplot, 
                       here("figures", "flipper_boxplot_powerpoint.png"), 
                       size = 20, res = 300, scaling = 3)
# Out:
# pdf
#   2
# pdf
#   2
# pdf
#   2

# %%
save_flipper_plot_svg <- function(boxplot, 
                                  filename, size, scaling){
    size_inches = size/2.54
    svglite(filename, width   = size_inches, 
                      height  = size_inches, 
                      scaling = scaling)
    print(boxplot)
    dev.off()
}

flipper_boxplot <- plot_boxplot(penguins_clean, 
                                species, flipper_length_mm, 
                                "Species", "Flipper Length (mm)", 
                                species_colours)

save_flipper_plot_svg(flipper_boxplot, 
                       here("figures", "flipper_boxplot_report.svg"), 
                       size = 20, scaling = 2)

save_flipper_plot_svg(flipper_boxplot, 
                       here("figures", "flipper_boxplot_poster.svg"), 
                       size = 40, scaling = 4)

save_flipper_plot_svg(flipper_boxplot, 
                       here("figures", "flipper_boxplot_powerpoint.svg"), 
                       size = 20, scaling = 3)
# Out:
# pdf
#   2
# pdf
#   2
# pdf
#   2
